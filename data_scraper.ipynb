# %% [markdown]
# # Automatic data scraping of basketball statistics on RealGM

# %% [markdown]
# ## Define get_data function

# %%
import urllib.request as urllib
from bs4 import BeautifulSoup
import csv
import pandas as pd
import os

# %%
def get_data(
        league_id,
        league_name,
        league_year,
        stat_type='Averages'
):


    # Find all pages with valid stat tables

    table_list = []

    # Use and append positions
    positions = ['C', 'PF', 'SF', 'SG', 'PG']

    for position in positions:
        page_count = 0
        while True:
            page_count += 1
            url = f"http://basketball.realgm.com/international/league/{league_id}/{league_name}/stats/{league_year}/{stat_type}/Qualified/All/points/{position}/desc/{page_count}/Regular_Season"
            print("Parsing " + url)
            page = urllib.urlopen(url)
            soup = BeautifulSoup(page, 'html.parser')
            table = soup.find('table')
            if table is None:
                print('No table data found. Exiting...')
                break
            else:
                table_list.append((position,table))

    # Get column names
    table = table_list[0][1]
    columns = table.find_all('th')
    columns = [column.text for column in columns]
    columns.insert(4, 'Position')

    # initialize csv file
    with open(f"Data/{league_name}_{league_year}_{stat_type}.csv", 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(columns)

        # write data to csv file
        for table in table_list:
            position = table[0]
            table_data = table[1]

            rows = table_data.find_all('tr')

            for row in rows:
                cells = row.find_all('td')
                if len(cells) == 0:
                    continue
                row_data = [cell.text for cell in cells]
                row_data.insert(4, position)
                writer.writerow(row_data)

    print(str(len(table_list)) + " pages parsed. Data saved to " + f"RealGM_data/{league_name}_{league_year}_averages.csv")

# %% [markdown]
# ## Running function

# %%
get_data(
    '131', 
    'PBA--Commissioners-Cup', 
    '2024',
    'Totals'
)
get_data(
    '130', 
    'PBA--Philippine-Cup', 
    '2024',
    'Totals'
)
get_data(
    '105',
    'Japanese-BLeague',
    '2024',
    'Totals'
)
get_data(
    '63', 
    'South-Korean-KBL', 
    '2024',
    'Totals'
)
# Out:
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/C/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/C/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/PF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/PF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/SF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/SF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/SG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/SG/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/PG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/131/PBA--Commissioners-Cup/stats/2024/Totals/Qualified/All/points/PG/desc/2/Regular_Season
# No table data found. Exiting...
# 5 pages parsed. Data saved to RealGM_data/PBA--Commissioners-Cup_2024_averages.csv
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/C/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/C/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/PF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/PF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/SF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/SF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/SG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/SG/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/PG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/130/PBA--Philippine-Cup/stats/2024/Totals/Qualified/All/points/PG/desc/2/Regular_Season
# No table data found. Exiting...
# 5 pages parsed. Data saved to RealGM_data/PBA--Philippine-Cup_2024_averages.csv
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/C/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/C/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/PF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/PF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/SF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/SF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/SG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/SG/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/PG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Totals/Qualified/All/points/PG/desc/2/Regular_Season
# No table data found. Exiting...
# 5 pages parsed. Data saved to RealGM_data/Japanese-BLeague_2024_averages.csv
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/C/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/C/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/PF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/PF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/SF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/SF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/SG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/SG/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/PG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/63/South-Korean-KBL/stats/2024/Totals/Qualified/All/points/PG/desc/2/Regular_Season
# No table data found. Exiting...
# 5 pages parsed. Data saved to RealGM_data/South-Korean-KBL_2024_averages.csv

# %% [markdown]
# ## CSV file checking

# %%
# read csv files of each league 

pba_df = pd.read_csv('Data/PBA--Commissioners-Cup_2024_Totals.csv')
pba_df2 = pd.read_csv('Data/PBA--Philippine-Cup_2024_Totals.csv')
japan_df = pd.read_csv('Data/Japanese-BLeague_2024_Totals.csv')
korean_df = pd.read_csv('Data/South-Korean-KBL_2024_Totals.csv')

# %%
# get head of each dataframe

print(pba_df.head())
print(bleague_df.head())
print(kbl_df.head())
# Out:
#    #                   Player  Team  GP Position   MPG   PPG   FGM   FGA  \
# 0  1  Rondae Hollis-Jefferson   TNT  10        C  41.2  34.6  12.9  26.2
# 1  2          Thomas Robinson  NLEX   4        C  37.3  34.5  12.8  22.3
# 2  3         Suleiman Braimoh   MER   5        C  42.7  32.8  11.6  25.4
# 3  4        Christopher Ortiz  BLAC  11        C  41.2  25.7   9.5  21.8
# 4  5           DaJuan Summers   ROS   4        C  39.6  24.8   7.5  19.5
#
#      FG%  ...   FTA    FT%  ORB   DRB   RPG  APG  SPG  BPG  TOV   PF
# 0  0.492  ...  11.0  0.691  2.5   9.3  11.8  6.6  2.2  1.4  3.2  2.6
# 1  0.573  ...  14.0  0.625  3.0  10.3  13.3  3.5  1.8  1.8  5.8  4.0
# 2  0.457  ...  10.4  0.692  3.4   8.6  12.0  2.8  2.2  0.8  3.6  2.2
# 3  0.438  ...   6.5  0.746  1.5   8.9  10.4  4.9  1.4  0.7  3.2  1.8
# 4  0.385  ...   7.3  0.862  2.3   7.0   9.3  2.8  1.0  1.5  3.5  3.3
#
# [5 rows x 24 columns]
#    #          Player  Team  GP Position   MPG   PPG  FGM   FGA    FG%  ...  \
# 0  1     John Mooney   CHI  40        C  31.2  18.8  7.5  12.9  0.582  ...
# 1  2       Ivan Buva   TOY  33        C  28.4  18.3  6.7  13.4  0.500  ...
# 2  3      Shawn Long  OSAK  44        C  30.4  18.2  7.2  12.4  0.585  ...
# 3  4        Nick Kay  SHIM  44        C  32.6  17.0  6.0  12.0  0.499  ...
# 4  5  Sebastian Saiz   TOY  43        C  25.9  16.7  6.4  11.1  0.578  ...
#
#    FTA    FT%  ORB  DRB   RPG  APG  SPG  BPG  TOV   PF
# 0  4.3  0.771  3.7  7.9  11.6  2.3  1.1  0.6  1.3  2.2
# 1  5.6  0.780  2.7  7.2   9.9  1.6  0.4  0.4  2.2  1.7
# 2  6.5  0.579  4.3  6.4  10.8  2.5  0.8  0.9  2.6  2.2
# 3  4.0  0.864  3.1  5.8   8.8  3.3  1.3  0.5  1.5  1.7
# 4  4.4  0.780  3.0  5.0   8.0  1.0  0.9  0.7  1.3  2.0
#
# [5 rows x 24 columns]
#    #            Player    Team  GP Position   MPG   PPG   FGM   FGA    FG%  \
# 0  1     Jameel Warney     SKK  49        C  34.1  24.0  10.4  21.3  0.488
# 1  2     Kofi Cockburn     SAM  48        C  28.9  23.6   9.7  16.9  0.576
# 2  3  Andrew Nicholson  ETLAND  47        C  26.1  23.3   8.9  17.7  0.501
# 3  4        Gaige Prim     MOB  51        C  23.9  20.6   8.2  14.6  0.562
# 4  5    Chinanu Onuaku     GOY  43        C  31.5  19.0   7.6  14.0  0.541
#
#    ...  FTA    FT%  ORB  DRB   RPG  APG  SPG  BPG  TOV   PF
# 0  ...  3.9  0.563  3.4  8.0  11.5  4.5  1.1  1.1  1.6  1.3
# 1  ...  6.7  0.623  5.4  6.3  11.8  2.3  0.5  0.8  2.9  1.9
# 2  ...  3.9  0.811  1.5  6.3   7.8  0.9  0.6  0.4  1.7  1.7
# 3  ...  5.0  0.808  2.8  5.2   8.0  1.7  0.9  0.5  1.6  2.3
# 4  ...  4.5  0.710  3.3  9.1  12.4  4.0  1.4  1.0  3.3  2.9
#
# [5 rows x 24 columns]

# %%
get_data(
    '105',
    'Japanese-BLeague',
    '2024',
    'Averages'
)
# Out:
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/C/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/C/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/PF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/PF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/SF/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/SF/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/SG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/SG/desc/2/Regular_Season
# No table data found. Exiting...
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/PG/desc/1/Regular_Season
# Parsing http://basketball.realgm.com/international/league/105/Japanese-BLeague/stats/2024/Averages/Qualified/All/points/PG/desc/2/Regular_Season
# No table data found. Exiting...
# 5 pages parsed. Data saved to RealGM_data/Japanese-BLeague_2024_averages.csv

# %% [markdown]
# ## Test cells

# %%
# print duplicate rows in pba_df dropping the position column

pba_df_drop = pba_df.drop(columns=['Position'])

pba_df_drop.duplicated()

# print rows in pba_df with the same name

pba_df_names = pba_df['Player']
pba_df[pba_df_names.duplicated()]
# Out:
#      #              Player Team  GP Position   MPG  PPG  FGM  FGA    FG%  ...  \
# 76  10  Celedonio Trollano  SMB  15       SG  23.8  9.5  3.5  6.7  0.515  ...
#
#     FTA    FT%  ORB  DRB  RPG  APG  SPG  BPG  TOV   PF
# 76  1.9  0.759  1.5  2.7  4.2  0.9  0.5  0.2  1.1  1.5
#
# [1 rows x 24 columns]

# %%
# print all matches for celedonio trollano

pba_df[pba_df['Player'] == 'Celedonio Trollano']
# Out:
#      #              Player  Team  GP Position   MPG   PPG  FGM   FGA    FG%  \
# 67   1  Celedonio Trollano  NLEX   7       SG  31.4  17.4  6.0  12.4  0.483
# 76  10  Celedonio Trollano   SMB  15       SG  23.8   9.5  3.5   6.7  0.515
#
#     ...  FTA    FT%  ORB  DRB  RPG  APG  SPG  BPG  TOV   PF
# 67  ...  4.1  0.828  0.3  2.9  3.1  2.7  0.9  0.1  1.9  1.6
# 76  ...  1.9  0.759  1.5  2.7  4.2  0.9  0.5  0.2  1.1  1.5
#
# [2 rows x 24 columns]
