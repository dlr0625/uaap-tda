# %%
import numpy as np
import pandas as pd

# %%
file_path = 'UAAP Dataset/UAAP_2024_averages.csv'
data = pd.read_csv(file_path)
features = data[['PPG', 'RPG', 'APG', 'SPG', 'BPG', 'TOV']]

# Load your dataset

data.head()
data.columns
# Out:
# Index(['Player', 'Team', 'GP', 'Position', 'MPG', 'PPG', 'FGM', 'FGA', 'FG%',
#        '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'RPG', 'APG',
#        'SPG', 'BPG', 'TOV', 'PF'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from scipy.spatial import distance_matrix
import gudhi as gd
import matplotlib.pyplot as plt

# %%
# Selecting relevant features
data = pd.read_csv(file_path)
features = data[['PPG', 'RPG', 'APG', 'SPG', 'BPG', 'TOV']]

# Standardizing the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Compute the distance matrix
distance_matrix = squareform(pdist(features_scaled, metric='euclidean'))

# Using GUDHI to compute the Rips complex and its persistence
rips_complex = gd.RipsComplex(distance_matrix=distance_matrix, max_edge_length=2)
simplex_tree = rips_complex.create_simplex_tree(max_dimension=2)
diagram = simplex_tree.persistence()

# Set up matplotlib subplots for side-by-side visualization
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # Adjust figsize to fit your screen

# Plot persistence diagram on the first subplot
gd.plot_persistence_diagram(diagram, axes=axs[0])
axs[0].set_title('Persistence Diagram')

# Plot persistence barcode on the second subplot
gd.plot_persistence_barcode(diagram, axes=axs[1])
axs[1].set_title('Persistence Barcode')

plt.tight_layout()
plt.show()

# %%
# Selecting relevant features
data = pd.read_csv(file_path)
data = data[data['Position']== 'G']
features = data[['PPG', 'RPG', 'APG', 'SPG', 'BPG', 'TOV']]

# Standardizing the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Compute the distance matrix
distance_matrix = squareform(pdist(features_scaled, metric='euclidean'))

# Using GUDHI to compute the Rips complex and its persistence
rips_complex = gd.RipsComplex(distance_matrix=distance_matrix, max_edge_length=2)
simplex_tree = rips_complex.create_simplex_tree(max_dimension=2)
diagram = simplex_tree.persistence()

# Set up matplotlib subplots for side-by-side visualization
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # Adjust figsize to fit your screen

# Plot persistence diagram on the first subplot
gd.plot_persistence_diagram(diagram, axes=axs[0])
axs[0].set_title('Persistence Diagram')

# Plot persistence barcode on the second subplot
gd.plot_persistence_barcode(diagram, axes=axs[1])
axs[1].set_title('Persistence Barcode')

plt.tight_layout()
plt.show()

# %%
# Selecting relevant features
data = pd.read_csv(file_path)
data = data[data['Position']== 'F']
features = data[['PPG', 'RPG', 'APG', 'SPG', 'BPG', 'TOV']]

# Standardizing the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Compute the distance matrix
distance_matrix = squareform(pdist(features_scaled, metric='euclidean'))

# Using GUDHI to compute the Rips complex and its persistence
rips_complex = gd.RipsComplex(distance_matrix=distance_matrix, max_edge_length=2)
simplex_tree = rips_complex.create_simplex_tree(max_dimension=2)
diagram = simplex_tree.persistence()

# Set up matplotlib subplots for side-by-side visualization
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # Adjust figsize to fit your screen

# Plot persistence diagram on the first subplot
gd.plot_persistence_diagram(diagram, axes=axs[0])
axs[0].set_title('Persistence Diagram')

# Plot persistence barcode on the second subplot
gd.plot_persistence_barcode(diagram, axes=axs[1])
axs[1].set_title('Persistence Barcode')

plt.tight_layout()
plt.show()

# %%
# Selecting relevant features
data = pd.read_csv(file_path)
data = data[data['Position']== 'C']
features = data[['PPG', 'RPG', 'APG', 'SPG', 'BPG', 'TOV']]

# Standardizing the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Compute the distance matrix
distance_matrix = squareform(pdist(features_scaled, metric='euclidean'))

# Using GUDHI to compute the Rips complex and its persistence
rips_complex = gd.RipsComplex(distance_matrix=distance_matrix, max_edge_length=2)
simplex_tree = rips_complex.create_simplex_tree(max_dimension=2)
diagram = simplex_tree.persistence()

# Set up matplotlib subplots for side-by-side visualization
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # Adjust figsize to fit your screen

# Plot persistence diagram on the first subplot
gd.plot_persistence_diagram(diagram, axes=axs[0])
axs[0].set_title('Persistence Diagram')

# Plot persistence barcode on the second subplot
gd.plot_persistence_barcode(diagram, axes=axs[1])
axs[1].set_title('Persistence Barcode')

plt.tight_layout()
plt.show()

# %%
data_guards = data[data['Position']== 'C']

features = data_guards[['PPG', 'RPG', 'APG', 'SPG', 'BPG']]

# Standardizing the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Compute the distance matrix
distance_matrix = squareform(pdist(features_scaled, metric='euclidean'))

# Using GUDHI to compute the Rips complex and its persistence
rips_complex = gd.RipsComplex(distance_matrix=distance_matrix, max_edge_length=2)
simplex_tree = rips_complex.create_simplex_tree(max_dimension=2)
diagram = simplex_tree.persistence()

# Visualizing the persistence diagram and barcode
persistence_diagram = gd.plot_persistence_diagram(diagram)
persistence_barcode = gd.plot_persistence_barcode(diagram)

persistence_diagram, persistence_barcode
# Out:
# (<Axes: title={'center': 'Persistence diagram'}, xlabel='Birth', ylabel='Death'>,
#  <Axes: title={'center': 'Persistence barcode'}>)

# %%
# Out:
#                  Player  Team  GP Position    MPG   PPG   FGM    FGA   FG%  \
# 1          Kouame, Ange  ADMU  14        C  27.30  11.6  65.0  118.0  54.8
# 6             Chiu, Geo  ADMU  14        C  10.14   2.1  10.0   25.0  38.5
# 10            Ong, Kyle  ADMU   5        C   1.51   0.3   1.0    2.0  50.0
# 12          Faye, Adama   UST  13        C  30.57  11.4  60.0  132.0  45.1
# 24         Herrera, Ian   UST  11        C   3.42   0.4   0.0   11.0   0.0
# 29    Phillips, Michael  DLSU  10        C  25.17   9.4  36.0   76.0  47.4
# 32        Cortez, Raven  DLSU  11        C  10.58   5.2  22.0   42.0  56.5
# 34   Phillips, Benjamin  DLSU  13        C  14.17   4.6  21.0   53.0  41.0
# 35      Nwankwo, Bright  DLSU  14        C  15.19   3.9  21.0   46.0  45.7
# 47    Tchuente, Patrick   FEU  14        C  19.19   5.1  26.0   65.0  40.0
# 67       Mahinay, Germy    NU  14        C   5.53   1.0   5.0   21.0  24.0
# ...
